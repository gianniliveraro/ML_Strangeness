# %% [markdown]
# **Autor:** Gianni S. S. Liveraro
#
# **Última Atualização:** Set/2023
#
# **Descrição:** Notebook interativo para análise exploratória de dados tabelados. Para um arquivo .csv de input, as análises possíveis são:
#
# - **Exploratory Table:** Atributos estatísticos são calculados para todas as features de acordo com o seu tipo (numérica ou categórica): média, desvio-padrão, mediana, intervalo interquartil, min/max, N. de NaN, Frequências e etc.
#
# - **Exploratory Plots:** Permite plotar gráficos (histogramas, scatterplots, barplots, crosstables e etc) de forma interativa.
#
# - **Correlation Plots:** Plota duas matrizes de correlação. A primeira com os coeficientes de Spearman para as features numéricas e a segunda com os valores de Chi-Quadrado para as features categóricas.
#
# Um exemplo de uso das funções está incluso na última seção deste Notebook.
#
# Obs.: As funções/bibliotecas utilizadas são importadas do script auxiliar "ExploratoryClass.py". Sem ele, nada funciona.

# %%
# Initial Settings
FileName = 'MCSigma0GammasTree' # File name, should be a .csv or parquet file!!
PROJECT_PATH = '/storage1/liveraro/ML_Strangeness/' # Project main directory path
FILE_PATH = PROJECT_PATH+'Dataset/Interim/{}.parquet'.format(FileName)

# %%
# JUST EXECUTE THIS CELL. THERE IS NOTHING TO CHANGE HERE!

# Loading libraries and custom functions/classes!
import sys

sys.path.insert(0,PROJECT_PATH+'Notebooks/')
from ExploratoryClass import *

# Load the dataset
df = pd.read_parquet(FILE_PATH)

# Creating directory to save analysis results
EXPLORATORYANALYSIS_PATH = PROJECT_PATH+'DEV/Gianni/Codes/ExploratoryAnalysis/'
os.makedirs(EXPLORATORYANALYSIS_PATH, exist_ok=True)

# %%
# Table Settings

## It determines minimum number of unique values to consider a feature as categorical
categorical_threshold = 5  ## You should adjust this threshold based on your data

## Flags:
SaveTable = False # If True, save table as.XLSX file in ../ExploratoryAnalysis
SaveFigures = False # If True, save 1D plots for each feature in ../ExploratoryAnalysis/SavedPlots/

# Creating table
print("Number of entries/rows (dataframe size): ", len(df))
summary_df, sample, categorical_features, numerical_features, ListGoodFeatures  = feature_summary(df, EXPLORATORYANALYSIS_PATH, FileName, categorical_threshold, SavePlots=SaveFigures, SaveTable=SaveTable)
categorical_list, numerical_list = categorical_features.copy(), numerical_features.copy()
summary_df
# Out:
# Number of entries/rows (dataframe size):  13984185
#  Processing Feature 43 out of 44
#                Feature    Dtype          Mean           STD        Median  \
# 0           fPosITSCls    int32  4.080000e+00  1.410000e+00  4.000000e+00
# 1           fNegITSCls    int32  4.070000e+00  1.410000e+00  4.000000e+00
# 2        fPosITSClSize   uint32  6.755962e+07  4.121921e+07  6.959923e+07
# 3        fNegITSClSize   uint32  6.627832e+07  3.978804e+07  6.948454e+07
# 4          fPosTPCRows    uint8  1.255300e+02  4.206000e+01  1.480000e+02
# 5          fNegTPCRows    uint8  1.256700e+02  4.093000e+01  1.480000e+02
# 6       fPosTPCSigmaPi  float32 -6.480000e+01  2.563600e+02  1.131308e+00
# 7       fNegTPCSigmaPi  float32 -5.995000e+01  2.433700e+02  1.093218e+00
# 8       fPosTPCSigmaPr  float32 -7.750000e+01  2.520900e+02 -1.195762e+01
# 9       fNegTPCSigmaPr  float32 -7.121000e+01  2.402400e+02 -1.217468e+01
# 10      fPosTPCSigmaEl  float32 -6.977000e+01  2.547500e+02 -3.362529e+00
# 11      fNegTPCSigmaEl  float32 -6.434000e+01  2.421400e+02 -3.353887e+00
# 12       fTOFSigmaLaPr  float32 -7.935900e+02  7.766000e+02 -1.000000e+03
# 13       fTOFSigmaLaPi  float32 -8.006300e+02  7.161600e+02 -1.000000e+03
# 14      fTOFSigmaALaPi  float32 -7.902500e+02  7.195100e+02 -1.000000e+03
# 15      fTOFSigmaALaPr  float32 -8.058100e+02  7.442800e+02 -1.000000e+03
# 16   fTOFSigmaK0PiPlus  float32 -7.609800e+02  1.060950e+03 -1.000000e+03
# 17  fTOFSigmaK0PiMinus  float32 -7.726400e+02  1.049350e+03 -1.000000e+03
# 18         fLambdaMass  float32  1.290000e+00  2.200000e-01  1.201235e+00
# 19     fAntiLambdaMass  float32  1.290000e+00  2.200000e-01  1.210686e+00
# 20          fGammaMass  float32  2.200000e-01  1.400000e-01  2.256661e-01
# 21     fKZeroShortMass  float32  4.100000e-01  9.000000e-02  4.176957e-01
# 22                 fPT  float32  1.020000e+00  7.700000e-01  7.988969e-01
# 23                 fQt  float32  1.000000e-01  7.000000e-02  8.690200e-02
# 24              fAlpha  float32  1.000000e-02  5.300000e-01  2.151649e-02
# 25             fPosEta  float32  1.000000e-02  4.400000e-01  1.400243e-02
# 26             fNegEta  float32  1.000000e-02  4.300000e-01  1.116552e-02
# 27              fV0Eta  float32  1.000000e-02  4.200000e-01  1.449853e-02
# 28                  fZ  float32  2.800000e-01  6.900000e+00  2.390911e-01
# 29           fV0radius  float32  5.840000e+00  7.400000e+00  3.085263e+00
# 30                 fPA  float32  9.000000e-02  1.100000e-01  4.774386e-02
# 31         fDCApostopv  float32 -4.100000e-01  1.800000e+00 -2.533135e-01
# 32         fDCAnegtopv  float32  4.200000e-01  1.840000e+00  2.557251e-01
# 33     fDCAV0daughters  float32  2.000000e-01  2.500000e-01  9.031327e-02
# 34          fDCAv0topv  float32  3.800000e-01  7.200000e-01  1.545173e-01
# 35            fPsiPair  float32  0.000000e+00  7.800000e-01  2.020412e-03
# 36             fV0type    uint8           NaN           NaN           NaN
# 37         fCentrality  float32  2.051000e+01  1.755000e+01  1.550000e+01
# 38      fSelHypothesis    uint8  4.220000e+00  3.130000e+00  2.000000e+00
# 39           fIsLambda     bool           NaN           NaN           NaN
# 40       fIsAntiLambda     bool           NaN           NaN           NaN
# 41            fIsGamma     bool           NaN           NaN           NaN
# 42       fIsKZeroShort     bool           NaN           NaN           NaN
# 43      fPDGCodeMother    int32  4.188601e+07  2.004145e+08 -1.000000e+00
#
#                                     IQ (Q1, Q3)  \
# 0                                    [3.0, 5.0]
# 1                                    [3.0, 5.0]
# 2                      [39845888.0, 73678848.0]
# 3                      [38993920.0, 73470803.0]
# 4                                [106.0, 152.0]
# 5                                [104.0, 152.0]
# 6    [-0.31588977575302124, 2.9468069076538086]
# 7    [-0.31781938672065735, 2.7908778190612793]
# 8     [-13.463408470153809, -5.905907154083252]
# 9      [-13.47606372833252, -6.943190574645996]
# 10    [-4.628871917724609, -0.7866714000701904]
# 11    [-4.598827838897705, -0.9216869473457336]
# 12                           [-1000.0, -1000.0]
# 13                           [-1000.0, -1000.0]
# 14                           [-1000.0, -1000.0]
# 15                           [-1000.0, -1000.0]
# 16                           [-1000.0, -1000.0]
# 17                           [-1000.0, -1000.0]
# 18      [1.118838906288147, 1.3818399906158447]
# 19     [1.1194192171096802, 1.3907864093780518]
# 20   [0.10041391104459763, 0.38082650303840637]
# 21    [0.3211722671985626, 0.49729591608047485]
# 22      [0.4897140562534332, 1.325735330581665]
# 23  [0.044411580078303814, 0.15807749703526497]
# 24    [-0.4654037058353424, 0.4767015278339386]
# 25   [-0.3494928181171417, 0.36907437443733215]
# 26  [-0.34990933537483215, 0.36743059754371643]
# 27  [-0.34491658210754395, 0.36386024951934814]
# 28      [-3.45780086517334, 3.9885101318359375]
# 29       [2.089033842086792, 6.166141986846924]
# 30   [0.010078053921461105, 0.1299770325422287]
# 31   [-0.8957780003547668, 0.16225266456604004]
# 32    [-0.1640174835920334, 0.9120461940765381]
# 33  [0.022803230211138725, 0.30951371788978577]
# 34   [0.05522484704852104, 0.42973971366882324]
# 35    [-0.5627663135528564, 0.5673319101333618]
# 36                                 [None, None]
# 37                                  [7.5, 28.5]
# 38                                   [1.0, 8.0]
# 39                                 [None, None]
# 40                                 [None, None]
# 41                                 [None, None]
# 42                                 [None, None]
# 43                                 [-1.0, -1.0]
#
#                                          Min, Max  Skewness  Kurtosis  \
# 0                                          [0, 7]      0.20      0.20
# 1                                          [0, 7]      0.20      0.20
# 2                                  [0, 268435455]      1.53      4.69
# 3                                  [0, 268435159]      1.50      4.90
# 4                                        [0, 152]     -1.88      2.77
# 5                                        [0, 152]     -1.86      2.87
# 6                      [-999.0, 1813.10302734375]     -3.34      9.30
# 7                     [-999.0, 2043.778076171875]     -3.59     10.94
# 8                     [-999.0, 701.9695434570312]     -3.38      9.43
# 9                    [-999.0, 170.81411743164062]     -3.60     10.97
# 10                    [-999.0, 1780.875244140625]     -3.35      9.34
# 11                   [-999.0, 1977.6715087890625]     -3.59     10.95
# 12                     [-1000.0, 26904.333984375]     13.33    251.40
# 13                     [-1000.0, 23711.935546875]     10.76    168.14
# 14                       [-1000.0, 25408.7578125]     10.47    162.33
# 15                     [-1000.0, 25950.248046875]     13.20    247.60
# 16                     [-1000.0, 28645.896484375]     12.76    198.29
# 17                       [-1000.0, 28518.0703125]     13.00    204.78
# 18        [1.0778424739837646, 3.413013219833374]      1.67      2.93
# 19       [1.0778424739837646, 3.8609683513641357]      1.61      2.71
# 20     [0.001021998468786478, 0.4232366383075714]     -0.08     -1.37
# 21       [0.27914080023765564, 0.742024838924408]     -0.14     -1.61
# 22       [0.02506200782954693, 47.92546844482422]      2.55     15.74
# 23  [3.5774425555246125e-07, 0.21161770820617676]      0.31     -1.10
# 24       [-10.658890724182129, 9.146245956420898]     -0.08      0.16
# 25      [-0.7999998331069946, 0.7999997735023499]     -0.03     -1.08
# 26      [-0.7999999523162842, 0.7999998331069946]     -0.02     -1.08
# 27      [-1.4987874031066895, 1.5051312446594238]     -0.03     -1.04
# 28      [-152.56507873535156, 166.02687072753906]      0.01      7.38
# 29       [1.2000038623809814, 198.62310791015625]      4.11     25.55
# 30                        [0.0, 0.45102658867836]      1.48      1.42
# 31        [-35.97715377807617, 21.73896026611328]     -1.34     15.37
# 32        [-20.50444793701172, 35.31789016723633]      1.35     14.91
# 33    [2.753309225056455e-08, 0.9999992847442627]      1.41      1.06
# 34      [9.805120498640463e-06, 51.2712516784668]      7.89    133.83
# 35      [-1.5707963705062866, 1.5707963705062866]     -0.00     -0.76
# 36                                   [None, None]       NaN       NaN
# 37                                    [0.0, 99.5]      1.44      2.29
# 38                                        [1, 14]      0.37     -1.64
# 39                                   [None, None]       NaN       NaN
# 40                                   [None, None]       NaN       NaN
# 41                                   [None, None]       NaN       NaN
# 42                                   [None, None]       NaN       NaN
# 43                           [-20433, 1000822080]      4.58     18.94
#
#                                             Frequency         N. Zeros  \
# 0                              {"4":6447098 (46.0 %)}   139738 (1.0 %)
# 1                              {"4":6386848 (46.0 %)}   139590 (1.0 %)
# 2                         {"71303168":300153 (2.0 %)}   139738 (1.0 %)
# 3                         {"71303168":306865 (2.0 %)}   139590 (1.0 %)
# 4                            {"152":5186354 (37.0 %)}  973130 (6.96 %)
# 5                            {"152":5167374 (37.0 %)}  878272 (6.28 %)
# 6             {"-999.0":973130 (7.000000000000001 %)}        2 (0.0 %)
# 7                           {"-999.0":878272 (6.0 %)}        2 (0.0 %)
# 8             {"-999.0":973130 (7.000000000000001 %)}        0 (0.0 %)
# 9                           {"-999.0":878272 (6.0 %)}        1 (0.0 %)
# 10            {"-999.0":973130 (7.000000000000001 %)}        2 (0.0 %)
# 11                          {"-999.0":878272 (6.0 %)}        2 (0.0 %)
# 12                      {"-1000.0":11617372 (83.0 %)}        0 (0.0 %)
# 13                      {"-1000.0":11756942 (84.0 %)}        0 (0.0 %)
# 14                      {"-1000.0":11617127 (83.0 %)}        0 (0.0 %)
# 15                      {"-1000.0":11757143 (84.0 %)}        0 (0.0 %)
# 16                      {"-1000.0":11617105 (83.0 %)}        0 (0.0 %)
# 17                      {"-1000.0":11756921 (84.0 %)}        0 (0.0 %)
# 18                 {"1.0778425931930542":133 (0.0 %)}        0 (0.0 %)
# 19                 {"1.0778425931930542":148 (0.0 %)}        0 (0.0 %)
# 20                 {"0.40789079666137695":19 (0.0 %)}        0 (0.0 %)
# 21                  {"0.5002247095108032":45 (0.0 %)}        0 (0.0 %)
# 22                   {"0.5967411398887634":9 (0.0 %)}        0 (0.0 %)
# 23                 {"0.20554208755493164":13 (0.0 %)}        0 (0.0 %)
# 24                  {"-0.5743436813354492":8 (0.0 %)}        0 (0.0 %)
# 25                 {"-0.6616412401199341":21 (0.0 %)}        0 (0.0 %)
# 26                  {"-0.609644889831543":17 (0.0 %)}        0 (0.0 %)
# 27                   {"0.6035779714584351":8 (0.0 %)}        1 (0.0 %)
# 28                   {"-4.327255725860596":7 (0.0 %)}        0 (0.0 %)
# 29                   {"2.0609161853790283":9 (0.0 %)}        0 (0.0 %)
# 30            {"0.0003452669770922512":52822 (0.0 %)}    28485 (0.2 %)
# 31                  {"0.1178642213344574":35 (0.0 %)}        0 (0.0 %)
# 32                 {"0.37278416752815247":46 (0.0 %)}        0 (0.0 %)
# 33                  {"0.06949671357870102":7 (0.0 %)}        0 (0.0 %)
# 34                  {"0.16729815304279327":9 (0.0 %)}        0 (0.0 %)
# 35               {"1.5707963705062866":34753 (0.0 %)}       12 (0.0 %)
# 36                          {"1":13984185 ( 100.0 %)}             None
# 37                             {"3.5":562397 (4.0 %)}    4291 (0.03 %)
# 38                             {"8":4725516 (34.0 %)}        0 (0.0 %)
# 39  {"False":13380182 ( 95.68 %), "True":604003 ( ...             None
# 40  {"False":13416574 ( 95.94 %), "True":567611 ( ...             None
# 41  {"False":13771224 ( 98.48 %), "True":212961 ( ...             None
# 42  {"False":10417631 ( 74.5 %), "True":3566554 ( ...             None
# 43                            {"-1":8888336 (64.0 %)}        0 (0.0 %)
#
#           N. Negatives  N. Uniques          N. NaN
# 0            0 (0.0 %)         7.0       0 (0.0 %)
# 1            0 (0.0 %)         7.0       0 (0.0 %)
# 2            0 (0.0 %)   1188749.0       0 (0.0 %)
# 3            0 (0.0 %)   1145766.0       0 (0.0 %)
# 4            0 (0.0 %)        84.0       0 (0.0 %)
# 5            0 (0.0 %)        84.0       0 (0.0 %)
# 6    4159762 (29.75 %)  10902890.0       0 (0.0 %)
# 7    4182293 (29.91 %)  10885840.0       0 (0.0 %)
# 8   11918891 (85.23 %)   7419078.0       0 (0.0 %)
# 9   12262741 (87.69 %)   7155783.0       0 (0.0 %)
# 10  11167157 (79.86 %)   9445856.0       0 (0.0 %)
# 11  11335487 (81.06 %)   9411324.0       0 (0.0 %)
# 12  13609773 (97.32 %)   2304342.0       0 (0.0 %)
# 13  13082728 (93.55 %)   2195494.0       0 (0.0 %)
# 14  13009617 (93.03 %)   2330188.0       0 (0.0 %)
# 15  13612239 (97.34 %)   2172359.0       0 (0.0 %)
# 16  12594715 (90.06 %)   2346238.0       0 (0.0 %)
# 17  12678292 (90.66 %)   2208729.0       0 (0.0 %)
# 18           0 (0.0 %)   4747240.0       0 (0.0 %)
# 19           0 (0.0 %)   4808064.0       0 (0.0 %)
# 20           0 (0.0 %)   9966271.0       0 (0.0 %)
# 21           0 (0.0 %)   5326931.0       0 (0.0 %)
# 22           0 (0.0 %)  11021763.0       0 (0.0 %)
# 23           0 (0.0 %)  10680508.0  35181 (0.25 %)
# 24   6892937 (49.29 %)  11969417.0       0 (0.0 %)
# 25    6851576 (49.0 %)  11477477.0       0 (0.0 %)
# 26    6879926 (49.2 %)  11468089.0       0 (0.0 %)
# 27    6852636 (49.0 %)  11364670.0       0 (0.0 %)
# 28   6736619 (48.17 %)  12876142.0       0 (0.0 %)
# 29           0 (0.0 %)  10860832.0       0 (0.0 %)
# 30           0 (0.0 %)   1304938.0       0 (0.0 %)
# 31   9688943 (69.29 %)  11941462.0       0 (0.0 %)
# 32   4301520 (30.76 %)  11909199.0       0 (0.0 %)
# 33           0 (0.0 %)  12616517.0       0 (0.0 %)
# 34           0 (0.0 %)  12471278.0       0 (0.0 %)
# 35    6978760 (49.9 %)  11732856.0      24 (0.0 %)
# 36                None         NaN       0 (0.0 %)
# 37           0 (0.0 %)       101.0       0 (0.0 %)
# 38           0 (0.0 %)        13.0       0 (0.0 %)
# 39                None         NaN       0 (0.0 %)
# 40                None         NaN       0 (0.0 %)
# 41                None         NaN       0 (0.0 %)
# 42                None         NaN       0 (0.0 %)
# 43  10988218 (78.58 %)       137.0       0 (0.0 %)

# %%
df['IsMotherSigma'] = (df['fPDGCodeMother'] == 3212)
#categorical_list.append('IsMotherSigma')
Exploratory_Plots(df, numerical_list, categorical_list, EXPLORATORYANALYSIS_PATH)
# Out:
# /storage1/liveraro/miniconda3/envs/ML_Env/lib/python3.12/site-packages/jupyter_client/session.py:721: UserWarning: Message serialization failed with:
# Out of range float values are not JSON compliant: nan
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
#   content = self.pack(content)
# HBox(children=(VBox(children=(Dropdown(description='x-axis:', options=(None, 'fPosITSCls', 'fNegITSCls', 'fPos…
# IMPORTANT: Do not click the "Set" buttom again!
# To refresh the options or the plot, run the cell again or just click the  "Update Plot" buttom.
# HBox(children=(VBox(children=(Dropdown(description='Plot Type', options=('Barplot', 'CrossTab'), value='Barplo…
# Output()
