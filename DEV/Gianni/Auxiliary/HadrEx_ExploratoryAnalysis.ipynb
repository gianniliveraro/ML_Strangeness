# %% [markdown]
# **Autor:** Gianni S. S. Liveraro
#
# **Última Atualização:** Set/2023
#
# **Descrição:** Notebook interativo para análise exploratória de dados tabelados. Para um arquivo .csv de input, as análises possíveis são:
#
# - **Exploratory Table:** Atributos estatísticos são calculados para todas as features de acordo com o seu tipo (numérica ou categórica): média, desvio-padrão, mediana, intervalo interquartil, min/max, N. de NaN, Frequências e etc.
#
# - **Exploratory Plots:** Permite plotar gráficos (histogramas, scatterplots, barplots, crosstables e etc) de forma interativa.
#
# - **Correlation Plots:** Plota duas matrizes de correlação. A primeira com os coeficientes de Spearman para as features numéricas e a segunda com os valores de Chi-Quadrado para as features categóricas.
#
# Um exemplo de uso das funções está incluso na última seção deste Notebook.
#
# Obs.: As funções/bibliotecas utilizadas são importadas do script auxiliar "ExploratoryClass.py". Sem ele, nada funciona.

# %%
# Initial Settings
FileName = 'MCSigma0FindableLambdasTree' # File name, should be a .csv or parquet file!!
PROJECT_PATH = '/storage1/liveraro/ML_Strangeness/' # Project main directory path
FILE_PATH = PROJECT_PATH+'Dataset/Processed/{}.parquet'.format(FileName)
StudyName = "FindableLambdas"

# %%
# JUST EXECUTE THIS CELL. THERE IS NOTHING TO CHANGE HERE!

# Loading libraries and custom functions/classes!
import sys

sys.path.insert(0,PROJECT_PATH+'Notebooks/')
from ExploratoryClass import *

# Load the dataset
df = pd.read_parquet(FILE_PATH)

# Creating directory to save analysis results
EXPLORATORYANALYSIS_PATH = PROJECT_PATH+'DEV/Gianni/Studies/{}/ExploratoryAnalysis/'.format(StudyName)
os.makedirs(EXPLORATORYANALYSIS_PATH, exist_ok=True)

# %%
# Table Settings

## It determines minimum number of unique values to consider a feature as categorical
categorical_threshold = 5  ## You should adjust this threshold based on your data

## Flags:
SaveTable = False # If True, save table as.XLSX file in ../ExploratoryAnalysis
SaveFigures = False # If True, save 1D plots for each feature in ../ExploratoryAnalysis/SavedPlots/

# Creating table
print("Number of entries/rows (dataframe size): ", len(df))
summary_df, sample, categorical_features, numerical_features, ListGoodFeatures  = feature_summary(df, EXPLORATORYANALYSIS_PATH, FileName, categorical_threshold, SavePlots=SaveFigures, SaveTable=SaveTable)
categorical_list, numerical_list = categorical_features.copy(), numerical_features.copy()
summary_df
# Out:
# Number of entries/rows (dataframe size):  4938483
#  Processing Feature 43 out of 44
#                Feature    Dtype          Mean           STD        Median  \
# 0           fPosITSCls    int32  3.320000e+00  2.550000e+00  4.000000e+00
# 1           fNegITSCls    int32  3.410000e+00  2.470000e+00  4.000000e+00
# 2        fPosITSClSize   uint32  5.810638e+07  5.503181e+07  5.695078e+07
# 3        fNegITSClSize   uint32  5.134415e+07  4.927663e+07  5.452595e+07
# 4          fPosTPCRows    uint8  1.185300e+02  5.266000e+01  1.510000e+02
# 5          fNegTPCRows    uint8  9.569000e+01  5.468000e+01  1.070000e+02
# 6       fPosTPCSigmaPi  float32 -2.102900e+02  4.250000e+02  3.390442e+00
# 7       fNegTPCSigmaPi  float32 -3.819200e+02  4.862200e+02 -5.471551e-01
# 8       fPosTPCSigmaPr  float32 -2.220400e+02  4.175700e+02  1.455211e+00
# 9       fNegTPCSigmaPr  float32 -3.901000e+02  4.797800e+02 -1.359116e+01
# 10      fPosTPCSigmaEl  float32 -2.182800e+02  4.204900e+02 -2.146381e+00
# 11      fNegTPCSigmaEl  float32 -3.838900e+02  4.846700e+02 -4.510425e+00
# 12       fTOFSigmaLaPr  float32 -5.296200e+02  1.379140e+03 -1.000000e+03
# 13       fTOFSigmaLaPi  float32 -9.005200e+02  6.615500e+02 -1.000000e+03
# 14      fTOFSigmaALaPi  float32 -5.484100e+02  1.171160e+03 -1.000000e+03
# 15      fTOFSigmaALaPr  float32 -9.006100e+02  7.410600e+02 -1.000000e+03
# 16   fTOFSigmaK0PiPlus  float32 -4.720400e+02  1.722890e+03 -1.000000e+03
# 17  fTOFSigmaK0PiMinus  float32 -8.873000e+02  8.714700e+02 -1.000000e+03
# 18         fLambdaMass  float32  1.130000e+00  1.400000e-01  1.116214e+00
# 19     fAntiLambdaMass  float32  1.630000e+00  3.700000e-01  1.605093e+00
# 20          fGammaMass  float32  2.200000e-01  1.400000e-01  2.247794e-01
# 21     fKZeroShortMass  float32  4.300000e-01  1.400000e-01  4.211960e-01
# 22                 fPT  float32  1.520000e+00  3.490000e+00  1.272482e+00
# 23                 fQt  float32  8.000000e-02  4.000000e-02  8.410688e-02
# 24              fAlpha  float32  6.000000e-01  2.700000e-01  6.351333e-01
# 25             fPosEta  float32 -0.000000e+00  4.500000e-01 -4.085828e-03
# 26             fNegEta  float32 -0.000000e+00  4.200000e-01 -2.775238e-03
# 27              fV0Eta  float32 -0.000000e+00  4.300000e-01 -3.765180e-03
# 28                  fZ  float32  8.000000e-02  1.168000e+01  5.297887e-02
# 29           fV0radius  float32  1.200000e+01  1.726000e+01  6.182261e+00
# 30                 fPA  float32  6.600000e-01  9.700000e-01  1.769840e-01
# 31         fDCApostopv  float32 -4.200000e-01  3.310000e+00 -3.127556e-02
# 32         fDCAnegtopv  float32  8.200000e-01  6.190000e+00  5.414551e-02
# 33     fDCAV0daughters  float32  1.460000e+00  3.980000e+00  2.555676e-01
# 34          fDCAv0topv  float32  2.500000e+00  5.360000e+00  8.347325e-01
# 35            fPsiPair  float32 -0.000000e+00  7.900000e-01  1.192767e-04
# 36             fV0type    uint8           NaN           NaN           NaN
# 37         fCentrality  float32  2.150000e+01  1.810000e+01  1.650000e+01
# 38      fSelHypothesis    uint8  4.700000e-01  1.370000e+00  0.000000e+00
# 39           fIsLambda     bool           NaN           NaN           NaN
# 40       fIsAntiLambda     bool           NaN           NaN           NaN
# 41            fIsGamma     bool           NaN           NaN           NaN
# 42       fIsKZeroShort     bool           NaN           NaN           NaN
# 43      fPDGCodeMother    int32  3.367793e+08  4.728995e+08  3.224000e+03
#
#                                    IQ (Q1, Q3)  \
# 0                                   [0.0, 5.0]
# 1                                   [0.0, 5.0]
# 2                            [0.0, 88355396.0]
# 3                            [0.0, 72546082.5]
# 4                                [99.0, 152.0]
# 5                                [54.0, 148.0]
# 6     [-2.1974457502365112, 13.36821174621582]
# 7                 [-999.0, 1.4140790104866028]
# 8     [-1.6886585354804993, 2.844568371772766]
# 9                [-999.0, -12.675612449645996]
# 10    [-5.404645919799805, 3.5254613161087036]
# 11               [-999.0, -2.4026559591293335]
# 12              [-1000.0, -2.1910253763198853]
# 13                          [-1000.0, -1000.0]
# 14                [-1000.0, 5.044142007827759]
# 15                          [-1000.0, -1000.0]
# 16                [-1000.0, 8.361458778381348]
# 17                          [-1000.0, -1000.0]
# 18    [1.1126937866210938, 1.1213462352752686]
# 19    [1.4317724108695984, 1.7927749752998352]
# 20  [0.15521173924207687, 0.27329881489276886]
# 21   [0.36570167541503906, 0.4804678112268448]
# 22    [0.8141440749168396, 1.8787074089050293]
# 23  [0.05991348531097174, 0.09799044951796532]
# 24    [0.5242258012294769, 0.7583158016204834]
# 25   [-0.38093869388103485, 0.377567395567894]
# 26  [-0.3482353985309601, 0.34432077407836914]
# 27  [-0.3668157011270523, 0.36372412741184235]
# 28     [-4.151658773422241, 4.307721138000488]
# 29    [1.8273096680641174, 15.113653659820557]
# 30  [0.033288925886154175, 0.7385663688182831]
# 31   [-0.5708751380443573, 0.1750037595629692]
# 32  [-0.34502270817756653, 1.3645612597465515]
# 33   [0.02851488906890154, 1.4732717871665955]
# 34    [0.12033410742878914, 2.734585404396057]
# 35    [-0.596316784620285, 0.5956034660339355]
# 36                                [None, None]
# 37                                 [7.5, 30.5]
# 38                                  [0.0, 1.0]
# 39                                [None, None]
# 40                                [None, None]
# 41                                [None, None]
# 42                                [None, None]
# 43                      [3212.0, 1000822080.0]
#
#                                        Min, Max  Skewness  Kurtosis  \
# 0                                        [0, 7]     -0.05     -1.30
# 1                                        [0, 7]     -0.12     -1.19
# 2                                [0, 268435392]      0.91      0.89
# 3                                [0, 268435424]      1.12      2.07
# 4                                      [0, 152]     -1.41      0.46
# 5                                      [0, 152]     -0.59     -1.05
# 6                  [-999.0, 1091.6461181640625]     -1.30     -0.26
# 7                   [-999.0, 472.0061340332031]     -0.48     -1.77
# 8                   [-999.0, 774.3690795898438]     -1.32     -0.25
# 9                   [-999.0, 487.1751403808594]     -0.48     -1.77
# 10                   [-999.0, 1379.67626953125]     -1.30     -0.25
# 11                  [-999.0, 399.1795959472656]     -0.48     -1.77
# 12                   [-1000.0, 27879.287109375]      8.62     92.05
# 13                     [-1000.0, 26352.8984375]     16.63    347.76
# 14                   [-1000.0, 28108.751953125]      7.63     76.69
# 15                   [-1000.0, 25565.818359375]     17.83    377.42
# 16                    [-1000.0, 28609.46484375]      8.34     80.17
# 17                   [-1000.0, 28163.548828125]     17.74    366.37
# 18     [1.0778425931930542, 45.694679260253906]     70.96   9515.46
# 19      [1.0778428316116333, 45.94232177734375]     17.27   1054.53
# 20   [0.0010240928968414664, 45.53961944580078]     35.17   4943.16
# 21     [0.27914223074913025, 45.54328155517578]     38.91   5000.04
# 22    [0.0016742716543376446, 957.076416015625]    124.53  22215.13
# 23   [8.148973392962944e-06, 10.54379940032959]     11.93   1390.76
# 24        [-11.855280876159668, 9.258056640625]     -2.76     13.78
# 25    [-0.7999997138977051, 0.7999992370605469]      0.01     -1.14
# 26    [-0.7999987602233887, 0.7999997138977051]      0.01     -1.04
# 27     [-3.9593257904052734, 4.015401840209961]      0.01     -1.08
# 28      [-511.8973083496094, 668.7435913085938]      0.03     27.92
# 29  [0.00014971521159168333, 911.5540161132812]      3.97     33.37
# 30                    [0.0, 3.1415927410125732]      1.52      0.77
# 31    [-121.33324432373047, 114.24427032470703]     -1.31     53.88
# 32    [-141.14065551757812, 156.29254150390625]      0.95     25.70
# 33  [1.1896210239115135e-08, 805.0070190429688]     10.52    474.92
# 34    [5.490228886628756e-06, 903.538330078125]      7.90    251.90
# 35    [-1.5707963705062866, 1.5707963705062866]     -0.00     -0.85
# 36                                 [None, None]       NaN       NaN
# 37                                  [0.0, 99.5]      1.38      2.03
# 38                                      [0, 12]      5.34     30.01
# 39                                 [None, None]       NaN       NaN
# 40                                 [None, None]       NaN       NaN
# 41                                 [None, None]       NaN       NaN
# 42                                 [None, None]       NaN       NaN
# 43                          [-5232, 1000822080]      0.69     -1.52
#
#                                   Frequency           N. Zeros  \
# 0                    {"0":1463301 (30.0 %)}  1463301 (29.63 %)
# 1                    {"4":1458119 (30.0 %)}  1331574 (26.96 %)
# 2                    {"0":1463301 (30.0 %)}  1463301 (29.63 %)
# 3                    {"0":1331574 (27.0 %)}  1331574 (26.96 %)
# 4                  {"152":2384338 (48.0 %)}   609610 (12.34 %)
# 5                   {"152":816147 (17.0 %)}   772027 (15.63 %)
# 6               {"-999.0":1106694 (22.0 %)}          0 (0.0 %)
# 7               {"-999.0":1891606 (38.0 %)}          2 (0.0 %)
# 8               {"-999.0":1106694 (22.0 %)}          1 (0.0 %)
# 9               {"-999.0":1891606 (38.0 %)}          0 (0.0 %)
# 10              {"-999.0":1106694 (22.0 %)}          0 (0.0 %)
# 11              {"-999.0":1891606 (38.0 %)}          0 (0.0 %)
# 12             {"-1000.0":3306280 (67.0 %)}          0 (0.0 %)
# 13             {"-1000.0":4603952 (93.0 %)}          0 (0.0 %)
# 14             {"-1000.0":3306167 (67.0 %)}          0 (0.0 %)
# 15             {"-1000.0":4604001 (93.0 %)}          0 (0.0 %)
# 16             {"-1000.0":3306165 (67.0 %)}          0 (0.0 %)
# 17             {"-1000.0":4603949 (93.0 %)}          0 (0.0 %)
# 18        {"1.1158967018127441":96 (0.0 %)}          0 (0.0 %)
# 19         {"1.0810527801513672":8 (0.0 %)}          0 (0.0 %)
# 20        {"0.27128517627716064":9 (0.0 %)}          0 (0.0 %)
# 21        {"0.36141443252563477":8 (0.0 %)}          0 (0.0 %)
# 22         {"1.0333982706069946":6 (0.0 %)}          0 (0.0 %)
# 23        {"0.09881970286369324":9 (0.0 %)}          0 (0.0 %)
# 24         {"0.5661895275115967":8 (0.0 %)}          0 (0.0 %)
# 25       {"-0.5626839399337769":11 (0.0 %)}          0 (0.0 %)
# 26        {"-0.5411465764045715":7 (0.0 %)}          0 (0.0 %)
# 27        {"-0.6427187919616699":5 (0.0 %)}          0 (0.0 %)
# 28         {"-8.900131225585938":4 (0.0 %)}          0 (0.0 %)
# 29         {"0.6613680720329285":5 (0.0 %)}          0 (0.0 %)
# 30  {"0.0003452669770922512":12342 (0.0 %)}      6874 (0.14 %)
# 31       {"-0.12026634812355042":7 (0.0 %)}          0 (0.0 %)
# 32       {"-0.03517674654722214":6 (0.0 %)}          0 (0.0 %)
# 33        {"0.07412391155958176":5 (0.0 %)}          0 (0.0 %)
# 34        {"0.03496723994612694":4 (0.0 %)}          0 (0.0 %)
# 35       {"1.5707963705062866":547 (0.0 %)}          2 (0.0 %)
# 36                 {"1":4938483 ( 100.0 %)}               None
# 37                   {"3.5":187340 (4.0 %)}      2168 (0.04 %)
# 38                   {"0":3565744 (72.0 %)}   3565744 (72.2 %)
# 39              {"True":4938483 ( 100.0 %)}               None
# 40             {"False":4938483 ( 100.0 %)}               None
# 41             {"False":4938483 ( 100.0 %)}               None
# 42             {"False":4938483 ( 100.0 %)}               None
# 43          {"1000822080":1661803 (34.0 %)}          0 (0.0 %)
#
#          N. Negatives  N. Uniques      N. NaN
# 0           0 (0.0 %)         7.0   0 (0.0 %)
# 1           0 (0.0 %)         7.0   0 (0.0 %)
# 2           0 (0.0 %)    690816.0   0 (0.0 %)
# 3           0 (0.0 %)    601781.0   0 (0.0 %)
# 4           0 (0.0 %)       141.0   0 (0.0 %)
# 5           0 (0.0 %)       146.0   0 (0.0 %)
# 6   1659936 (33.61 %)   3360882.0   0 (0.0 %)
# 7   2770749 (56.11 %)   2606568.0   0 (0.0 %)
# 8   1514953 (30.68 %)   3286278.0   0 (0.0 %)
# 9   4914059 (99.51 %)   1847131.0   0 (0.0 %)
# 10  3110148 (62.98 %)   3347200.0   0 (0.0 %)
# 11  4335201 (87.78 %)   2524740.0   0 (0.0 %)
# 12  4300429 (87.08 %)   1620816.0   0 (0.0 %)
# 13  4773156 (96.65 %)    334172.0   0 (0.0 %)
# 14  3432627 (69.51 %)   1604169.0   0 (0.0 %)
# 15  4896666 (99.15 %)    332058.0   0 (0.0 %)
# 16  3413087 (69.11 %)   1606551.0   0 (0.0 %)
# 17  4738613 (95.95 %)    334154.0   0 (0.0 %)
# 18          0 (0.0 %)    824546.0   0 (0.0 %)
# 19          0 (0.0 %)   3642182.0   0 (0.0 %)
# 20          0 (0.0 %)   4161965.0   0 (0.0 %)
# 21          0 (0.0 %)   3758654.0   0 (0.0 %)
# 22          0 (0.0 %)   4473553.0   0 (0.0 %)
# 23          0 (0.0 %)   4121551.0  59 (0.0 %)
# 24    191477 (3.88 %)   3941410.0   0 (0.0 %)
# 25  2482631 (50.27 %)   4473832.0   0 (0.0 %)
# 26  2479457 (50.21 %)   4679721.0   0 (0.0 %)
# 27  2482112 (50.26 %)   4573996.0   0 (0.0 %)
# 28  2446869 (49.55 %)   4811994.0   0 (0.0 %)
# 29          0 (0.0 %)   4746508.0   0 (0.0 %)
# 30          0 (0.0 %)   2293879.0   0 (0.0 %)
# 31  2773318 (56.16 %)   4385919.0   0 (0.0 %)
# 32  1983828 (40.17 %)   4284496.0   0 (0.0 %)
# 33          0 (0.0 %)   4814371.0   0 (0.0 %)
# 34          0 (0.0 %)   4790211.0   0 (0.0 %)
# 35  2468969 (49.99 %)   4586421.0   0 (0.0 %)
# 36               None         NaN   0 (0.0 %)
# 37          0 (0.0 %)       101.0   0 (0.0 %)
# 38          0 (0.0 %)        12.0   0 (0.0 %)
# 39               None         NaN   0 (0.0 %)
# 40               None         NaN   0 (0.0 %)
# 41               None         NaN   0 (0.0 %)
# 42               None         NaN   0 (0.0 %)
# 43    131116 (2.65 %)        60.0   0 (0.0 %)

# %%
# Cell to create new derived variables
df['IsMotherSigma'] = (df['fPDGCodeMother'] == 3212)
categorical_list.append('IsMotherSigma')

# %%
# Exploratory plots
Exploratory_Plots(df, numerical_list, categorical_list, EXPLORATORYANALYSIS_PATH)
# Out:
# /storage1/liveraro/miniconda3/envs/ML_Env/lib/python3.12/site-packages/jupyter_client/session.py:721: UserWarning: Message serialization failed with:
# Out of range float values are not JSON compliant: nan
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
#   content = self.pack(content)
# HBox(children=(VBox(children=(Dropdown(description='x-axis:', options=(None, 'fPosITSCls', 'fNegITSCls', 'fPos…
# IMPORTANT: Do not click the "Set" buttom again!
# To refresh the options or the plot, run the cell again or just click the  "Update Plot" buttom.
# HBox(children=(VBox(children=(IntSlider(value=200, description='N. Bins', max=400), Dropdown(description='Log …
# Output()

# %%
# Todo esse bloco pra calcular a frequencia de cada categoria
b = Counter(df['fPDGCodeMother'].dropna())
total = sum(b.values())
stringaux = "{"
counter = 0
Arraysize = len(b.most_common())
for face, count in b.most_common():
    if counter==(Arraysize-1):
        stringaux = stringaux + "\""+str(face)+"\""+ ":" + str(count) + " ( " + str(round(100*count/total,2)) + " %)"
    else:
        stringaux = stringaux + "\""+str(face)+"\""+ ":" + str(count) + " ( " + str(round(100*count/total,2)) + " %), "
    counter = counter+1
    print()
stringaux = stringaux + "}"
stringaux
# Out:
# '{"1000822080":1661803 ( 33.65 %), "3212":1486737 ( 30.11 %), "3312":322495 ( 6.53 %), "3322":313395 ( 6.35 %), "3214":306020 ( 6.2 %), "3224":302611 ( 6.13 %), "3114":296463 ( 6.0 %), "-321":103468 ( 2.1 %), "130":50978 ( 1.03 %), "-211":23342 ( 0.47 %), "211":22613 ( 0.46 %), "3122":14826 ( 0.3 %), "4122":8539 ( 0.17 %), "310":7606 ( 0.15 %), "3334":6312 ( 0.13 %), "-2112":1854 ( 0.04 %), "-2212":1850 ( 0.04 %), "3112":1365 ( 0.03 %), "4132":960 ( 0.02 %), "3222":925 ( 0.02 %), "321":867 ( 0.02 %), "2212":662 ( 0.01 %), "2112":612 ( 0.01 %), "111":390 ( 0.01 %), "5122":223 ( 0.0 %), "-3122":173 ( 0.0 %), "-511":155 ( 0.0 %), "445":149 ( 0.0 %), "-521":135 ( 0.0 %), "10441":135 ( 0.0 %), "511":127 ( 0.0 %), "4232":110 ( 0.0 %), "443":86 ( 0.0 %), "521":53 ( 0.0 %), "20443":46 ( 0.0 %), "5232":43 ( 0.0 %), "-3112":37 ( 0.0 %), "10551":36 ( 0.0 %), "311":31 ( 0.0 %), "531":31 ( 0.0 %), "-531":29 ( 0.0 %), "113":26 ( 0.0 %), "-3222":25 ( 0.0 %), "-311":23 ( 0.0 %), "555":22 ( 0.0 %), "5132":20 ( 0.0 %), "553":15 ( 0.0 %), "441":14 ( 0.0 %), "221":12 ( 0.0 %), "-3312":8 ( 0.0 %), "-3322":6 ( 0.0 %), "-5132":5 ( 0.0 %), "-5122":5 ( 0.0 %), "100441":3 ( 0.0 %), "100553":2 ( 0.0 %), "11":1 ( 0.0 %), "200553":1 ( 0.0 %), "-5232":1 ( 0.0 %), "100443":1 ( 0.0 %), "313":1 ( 0.0 %)}'
